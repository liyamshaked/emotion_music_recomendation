# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/project/hrv_features_to_emotion.csv")

# %%
df.head(2000)
# Out:
#      Participant Id  Session ID  Video ID Name  Age    Male  Valence level  \
# 0                 1           1         1  M_W   21  Female              6
# 1                 1           1         2  M_W   21  Female              2
# 2                 1           1         3  M_W   21  Female              7
# 3                 1           1         4  M_W   21  Female              7
# 4                 1           1         5  M_W   21  Female              0
# ..              ...         ...       ...  ...  ...     ...            ...
# 401              12           3         3  Q_M   11     NaN              4
# 402              12           3         4  Q_M   11     NaN              4
# 403              12           3         5  Q_M   11     NaN              4
# 404              12           3         6  Q_M   11     NaN              2
# 405              12           3         7  Q_M   11     NaN              2
#
#     Arousal level  Dominance level     Happy  ... NN50 count pNN50 (%)  \
# 0               0                0  Moderate  ...        0.0  0.000000
# 1               4                2   VeryLow  ...        0.0  0.000000
# 2               6                6  Moderate  ...        0.0  0.000000
# 3               3                4  Moderate  ...        0.0  0.000000
# 4               8                8   VeryLow  ...        0.0  0.000000
# ..            ...              ...       ...  ...        ...       ...
# 401             9                0   VeryLow  ...        0.0  0.000000
# 402             0                0      High  ...        0.0  0.000000
# 403             0                0  Moderate  ...        0.0  0.000000
# 404             7                2   VeryLow  ...        1.0  4.545455
# 405             3                3   VeryLow  ...        0.0  0.000000
#
#     LF power (ms^2) HF power (ms^2) LF/HF ratio Total Power (ms^2)   SD1 (ms)  \
# 0               0.0             0.0         NaN                0.0   4.481467
# 1               0.0             0.0         NaN                0.0   4.481467
# 2               0.0             0.0         NaN                0.0   4.331894
# 3               0.0             0.0         NaN                0.0   4.294365
# 4               0.0             0.0         NaN                0.0   4.244095
# ..              ...             ...         ...                ...        ...
# 401             0.0             0.0         NaN                0.0  10.433786
# 402             0.0             0.0         NaN                0.0  13.019616
# 403             0.0             0.0         NaN                0.0  13.962615
# 404             0.0             0.0         NaN                0.0  15.114610
# 405             0.0             0.0         NaN                0.0   7.330542
#
#       SD2 (ms)   SD1/SD2                                     Sample Entropy
# 0     9.282317  0.482796  (np.float64(1.6094379124341003), {'Dimension':...
# 1     9.282317  0.482796  (np.float64(1.6094379124341003), {'Dimension':...
# 2    10.567848  0.409913  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 3    12.243533  0.350746  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 4     6.771444  0.626764  (np.float64(1.9459101490553135), {'Dimension':...
# ..         ...       ...                                                ...
# 401  17.223026  0.605804  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 402  16.571814  0.785648  (np.float64(0.6931471805599453), {'Dimension':...
# 403  35.044618  0.398424  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 404  46.917721  0.322151  (np.float64(0.8873031950009028), {'Dimension':...
# 405  12.338483  0.594120  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
#
# [406 rows x 49 columns]

# %%
print(df.columns)
# Out:
# Index(['Participant Id', 'Session ID', 'Video ID', 'Name', 'Age', 'Male',
#        'Valence level', 'Arousal level', 'Dominance level', 'Happy', 'Sad',
#        'Fear', 'Anger', 'Neutral', 'Disgust', 'Surprised', 'Familiarity Score',
#        'Emotion', 'Valence', 'Arousal', 'Four_Label', 'raw data', 'Gender',
#        'V_Label', 'A_Label', 'Four_Labels', 'R_Peaks', 'RR_Intervals',
#        'RR_Intervals_ms', 'Cleaned_RR_Intervals_ms', 'Mean RR (ms)',
#        'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
#        'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)',
#        'NN50 count', 'pNN50 (%)', 'LF power (ms^2)', 'HF power (ms^2)',
#        'LF/HF ratio', 'Total Power (ms^2)', 'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2',
#        'Sample Entropy'],
#       dtype='object')

# %%
neutral_df = df[[
    'Mean RR (ms)', 'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
    'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)', 'NN50 count', 'pNN50 (%)',
    'LF power (ms^2)', 'HF power (ms^2)', 'Total Power (ms^2)', 'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2', 'Neutral', 'Emotion'
]]

# %%
neutral_df.groupby('Neutral').size()
# Out:
# Neutral
# High          5
# Low          46
# Moderate     24
# VeryHigh     26
# VeryLow     305
# dtype: int64

# %%
neutral_df.groupby('Emotion').size()
# Out:
# Emotion
# Anger        28
# Disgust      34
# Fear         35
# Happy       120
# Mixed        88
# Neutral      37
# Sad          46
# Surprise     18
# dtype: int64

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE

# === STEP 1: DEFINE neutral_df ===
neutral_df = df[[  # your base dataframe
    'Mean RR (ms)', 'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
    'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)', 'NN50 count',
    'pNN50 (%)', 'LF power (ms^2)', 'HF power (ms^2)', 'Total Power (ms^2)',
    'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2', 'Neutral'
]].copy()

# === STEP 2: MAP 'Neutral' LABELS TO INTS ===
neutral_mapping = {'VeryLow': 0, 'Low': 0, 'Moderate': 1, 'High': 2, 'VeryHigh': 2}
neutral_df['Neutral Encoded'] = neutral_df['Neutral'].map(neutral_mapping)

# Drop NaNs just in case (or alternatively you can fillna)
neutral_df = neutral_df.dropna()

# === STEP 3: EXTRACT FEATURES AND LABELS ===
feature_cols = neutral_df.drop(columns=['Neutral', 'Neutral Encoded']).columns.tolist()
X = neutral_df[feature_cols].values
y = neutral_df['Neutral Encoded'].values

# === STEP 4: BALANCE WITH SMOTE ===
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# === STEP 5: ONE-HOT ENCODE LABELS ===
encoder = OneHotEncoder(sparse_output=False, categories='auto')
y_resampled_onehot = encoder.fit_transform(y_resampled.reshape(-1, 1))

# === STEP 6: SPLIT ===
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled_onehot, test_size=0.2, random_state=42, stratify=y_resampled
)

# === STEP 7: SCALE ===
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# === STEP 8: COMPUTE CLASS WEIGHTS (even after SMOTE) ===
y_resampled_flat = np.argmax(y_resampled_onehot, axis=1)
class_weights = compute_class_weight('balanced', classes=np.unique(y_resampled_flat), y=y_resampled_flat)
class_weight_dict = dict(enumerate(class_weights))
print("✅ Class weights:", class_weight_dict)

# === STEP 9: BUILD MODEL ===
def build_model(input_dim, optimizer_choice='adam', learning_rate=0.001):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dense(3, activation='softmax')
    ])

    if optimizer_choice == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer_choice == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    elif optimizer_choice == 'rmsprop':
        optimizer = RMSprop(learning_rate=learning_rate)
    else:
        raise ValueError("Unsupported optimizer. Use 'adam', 'sgd', or 'rmsprop'.")

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

optimizer_choice = 'adam'
learning_rate = 0.001
model = build_model(X_train.shape[1], optimizer_choice, learning_rate)

# === STEP 10: TRAIN ===
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=16,
    class_weight=class_weight_dict,
    verbose=1
)

# === STEP 11: EVALUATE ===
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"✅ Final Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# === STEP 12: CLASSIFICATION REPORT ===
y_pred_probs = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

print("\n✅ Classification Report:")
print(classification_report(y_true_classes, y_pred_classes))

# === STEP 13: CONFUSION MATRIX PLOT ===
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# === STEP 14: TRAINING HISTORY PLOT ===
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ✅ Class weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0)}
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3827 - loss: 1.0818 - val_accuracy: 0.4905 - val_loss: 1.0322
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5354 - loss: 0.9953 - val_accuracy: 0.5190 - val_loss: 0.9984
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5418 - loss: 0.9477 - val_accuracy: 0.5238 - val_loss: 0.9708
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6065 - loss: 0.9060 - val_accuracy: 0.5429 - val_loss: 0.9493
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5753 - loss: 0.8941 - val_accuracy: 0.5524 - val_loss: 0.9417
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5800 - loss: 0.8852 - val_accuracy: 0.5476 - val_loss: 0.9267
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6069 - loss: 0.8673 - val_accuracy: 0.5619 - val_loss: 0.9189
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6010 - loss: 0.8624 - val_accuracy: 0.5714 - val_loss: 0.9063
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6223 - loss: 0.8435 - val_accuracy: 0.5905 - val_loss: 0.9027
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6260 - loss: 0.8443 - val_accuracy: 0.5810 - val_loss: 0.8871
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6305 - loss: 0.8294 - val_accuracy: 0.5952 - val_loss: 0.8721
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6181 - loss: 0.8165 - val_accuracy: 0.6048 - val_loss: 0.8671
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6458 - loss: 0.7970 - val_accuracy: 0.5667 - val_loss: 0.8862
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6365 - loss: 0.8223 - val_accuracy: 0.5762 - val_loss: 0.8736
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6238 - loss: 0.7982 - val_accuracy: 0.5762 - val_loss: 0.8527
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6179 - loss: 0.8278 - val_accuracy: 0.6000 - val_loss: 0.8510
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6641 - loss: 0.7822 - val_accuracy: 0.6333 - val_loss: 0.8480
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6752 - loss: 0.7694 - val_accuracy: 0.6333 - val_loss: 0.8366
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6580 - loss: 0.7719 - val_accuracy: 0.6762 - val_loss: 0.8193
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6384 - loss: 0.7786 - val_accuracy: 0.6143 - val_loss: 0.8372
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7662 - loss: 0.6076 - val_accuracy: 0.7000 - val_loss: 0.6464
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7499 - loss: 0.6051 - val_accuracy: 0.7524 - val_loss: 0.6340
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7650 - loss: 0.5742 - val_accuracy: 0.7333 - val_loss: 0.6328
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7514 - loss: 0.6195 - val_accuracy: 0.7429 - val_loss: 0.6326
# Epoch 69/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7682 - loss: 0.6068 - val_accuracy: 0.7238 - val_loss: 0.6488
# Epoch 70/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7577 - loss: 0.5883 - val_accuracy: 0.7286 - val_loss: 0.6305
# Epoch 71/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7500 - loss: 0.6085 - val_accuracy: 0.7333 - val_loss: 0.6066
# Epoch 72/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7525 - loss: 0.5971 - val_accuracy: 0.7333 - val_loss: 0.6136
# Epoch 73/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7355 - loss: 0.6128 - val_accuracy: 0.7238 - val_loss: 0.6422
# Epoch 74/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7294 - loss: 0.6163 - val_accuracy: 0.7286 - val_loss: 0.6277
# Epoch 75/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7786 - loss: 0.5628 - val_accuracy: 0.7333 - val_loss: 0.6067
# Epoch 76/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7812 - loss: 0.5708 - val_accuracy: 0.7571 - val_loss: 0.6046
# Epoch 77/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7913 - loss: 0.5479 - val_accuracy: 0.7381 - val_loss: 0.6133
# Epoch 78/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7651 - loss: 0.5925 - val_accuracy: 0.7381 - val_loss: 0.6307
# Epoch 79/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7482 - loss: 0.5927 - val_accuracy: 0.7238 - val_loss: 0.6213
# Epoch 80/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7858 - loss: 0.5574 - val_accuracy: 0.7381 - val_loss: 0.5888
# Epoch 81/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7913 - loss: 0.5581 - val_accuracy: 0.7238 - val_loss: 0.6192
# Epoch 82/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7588 - loss: 0.5880 - val_accuracy: 0.7571 - val_loss: 0.6167
# Epoch 83/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7437 - loss: 0.6412 - val_accuracy: 0.7333 - val_loss: 0.6281
# Epoch 84/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7645 - loss: 0.5655 - val_accuracy: 0.7381 - val_loss: 0.6247
# Epoch 85/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7328 - loss: 0.6147 - val_accuracy: 0.7571 - val_loss: 0.6168
# Epoch 86/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7671 - loss: 0.5657 - val_accuracy: 0.7333 - val_loss: 0.5933
# Epoch 87/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7770 - loss: 0.5733 - val_accuracy: 0.7381 - val_loss: 0.5962
# Epoch 88/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7997 - loss: 0.5327 - val_accuracy: 0.7333 - val_loss: 0.6121
# Epoch 89/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7937 - loss: 0.5734 - val_accuracy: 0.7381 - val_loss: 0.5982
# Epoch 90/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7414 - loss: 0.5928 - val_accuracy: 0.7333 - val_loss: 0.6304
# Epoch 91/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7668 - loss: 0.5738 - val_accuracy: 0.7381 - val_loss: 0.5957
# Epoch 92/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7828 - loss: 0.5634 - val_accuracy: 0.7429 - val_loss: 0.6062
# Epoch 93/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7707 - loss: 0.5752 - val_accuracy: 0.7619 - val_loss: 0.5971
# Epoch 94/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7755 - loss: 0.5421 - val_accuracy: 0.7333 - val_loss: 0.5949
# Epoch 95/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7811 - loss: 0.5450 - val_accuracy: 0.7333 - val_loss: 0.5907
# Epoch 96/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8064 - loss: 0.4977 - val_accuracy: 0.7524 - val_loss: 0.5996
# Epoch 97/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7864 - loss: 0.5449 - val_accuracy: 0.7381 - val_loss: 0.5921
# Epoch 98/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7678 - loss: 0.5862 - val_accuracy: 0.7381 - val_loss: 0.5809
# Epoch 99/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7934 - loss: 0.5335 - val_accuracy: 0.7667 - val_loss: 0.5795
# Epoch 100/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7818 - loss: 0.5428 - val_accuracy: 0.7571 - val_loss: 0.5724
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7690 - loss: 0.5604
# ✅ Final Test Loss: 0.5724, Test Accuracy: 0.7571
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# ✅ Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.67      0.75        70
#            1       0.71      0.77      0.74        70
#            2       0.74      0.83      0.78        70
#
#     accuracy                           0.76       210
#    macro avg       0.76      0.76      0.76       210
# weighted avg       0.76      0.76      0.76       210

# %%
model.save("neutral_from_hrv_model.keras")
model.save("neutral_from_hrv_model.h5")

import joblib

# Save
joblib.dump(scaler, 'neutral_from_hrv_scaler.pkl')

from google.colab import files
files.download("neutral_from_hrv_model.keras")
files.download("neutral_from_hrv_model.h5")
files.download('neutral_from_hrv_scaler.pkl')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
