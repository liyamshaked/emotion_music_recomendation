# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/project/hrv_features_to_emotion.csv")

# %%
df.head(2000)
# Out:
#      Participant Id  Session ID  Video ID Name  Age    Male  Valence level  \
# 0                 1           1         1  M_W   21  Female              6
# 1                 1           1         2  M_W   21  Female              2
# 2                 1           1         3  M_W   21  Female              7
# 3                 1           1         4  M_W   21  Female              7
# 4                 1           1         5  M_W   21  Female              0
# ..              ...         ...       ...  ...  ...     ...            ...
# 401              12           3         3  Q_M   11     NaN              4
# 402              12           3         4  Q_M   11     NaN              4
# 403              12           3         5  Q_M   11     NaN              4
# 404              12           3         6  Q_M   11     NaN              2
# 405              12           3         7  Q_M   11     NaN              2
#
#     Arousal level  Dominance level     Happy  ... NN50 count pNN50 (%)  \
# 0               0                0  Moderate  ...        0.0  0.000000
# 1               4                2   VeryLow  ...        0.0  0.000000
# 2               6                6  Moderate  ...        0.0  0.000000
# 3               3                4  Moderate  ...        0.0  0.000000
# 4               8                8   VeryLow  ...        0.0  0.000000
# ..            ...              ...       ...  ...        ...       ...
# 401             9                0   VeryLow  ...        0.0  0.000000
# 402             0                0      High  ...        0.0  0.000000
# 403             0                0  Moderate  ...        0.0  0.000000
# 404             7                2   VeryLow  ...        1.0  4.545455
# 405             3                3   VeryLow  ...        0.0  0.000000
#
#     LF power (ms^2) HF power (ms^2) LF/HF ratio Total Power (ms^2)   SD1 (ms)  \
# 0               0.0             0.0         NaN                0.0   4.481467
# 1               0.0             0.0         NaN                0.0   4.481467
# 2               0.0             0.0         NaN                0.0   4.331894
# 3               0.0             0.0         NaN                0.0   4.294365
# 4               0.0             0.0         NaN                0.0   4.244095
# ..              ...             ...         ...                ...        ...
# 401             0.0             0.0         NaN                0.0  10.433786
# 402             0.0             0.0         NaN                0.0  13.019616
# 403             0.0             0.0         NaN                0.0  13.962615
# 404             0.0             0.0         NaN                0.0  15.114610
# 405             0.0             0.0         NaN                0.0   7.330542
#
#       SD2 (ms)   SD1/SD2                                     Sample Entropy
# 0     9.282317  0.482796  (np.float64(1.6094379124341003), {'Dimension':...
# 1     9.282317  0.482796  (np.float64(1.6094379124341003), {'Dimension':...
# 2    10.567848  0.409913  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 3    12.243533  0.350746  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 4     6.771444  0.626764  (np.float64(1.9459101490553135), {'Dimension':...
# ..         ...       ...                                                ...
# 401  17.223026  0.605804  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 402  16.571814  0.785648  (np.float64(0.6931471805599453), {'Dimension':...
# 403  35.044618  0.398424  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 404  46.917721  0.322151  (np.float64(0.8873031950009028), {'Dimension':...
# 405  12.338483  0.594120  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
#
# [406 rows x 49 columns]

# %%
print(df.columns)
# Out:
# Index(['Participant Id', 'Session ID', 'Video ID', 'Name', 'Age', 'Male',
#        'Valence level', 'Arousal level', 'Dominance level', 'Happy', 'Sad',
#        'Fear', 'Anger', 'Neutral', 'Disgust', 'Surprised', 'Familiarity Score',
#        'Emotion', 'Valence', 'Arousal', 'Four_Label', 'raw data', 'Gender',
#        'V_Label', 'A_Label', 'Four_Labels', 'R_Peaks', 'RR_Intervals',
#        'RR_Intervals_ms', 'Cleaned_RR_Intervals_ms', 'Mean RR (ms)',
#        'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
#        'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)',
#        'NN50 count', 'pNN50 (%)', 'LF power (ms^2)', 'HF power (ms^2)',
#        'LF/HF ratio', 'Total Power (ms^2)', 'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2',
#        'Sample Entropy'],
#       dtype='object')

# %%
anger_df = df[[
    'Mean RR (ms)', 'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
    'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)', 'NN50 count', 'pNN50 (%)',
    'LF power (ms^2)', 'HF power (ms^2)', 'Total Power (ms^2)', 'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2', 'Anger', 'Emotion'
]]

# %%
anger_df.groupby('Anger').size()
# Out:
# Anger
# High         12
# Low          47
# Moderate     26
# VeryHigh     31
# VeryLow     290
# dtype: int64

# %%
anger_df.groupby('Emotion').size()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-74d6e7f81785> in <cell line: 0>()
# ----> 1 anger_df.groupby('Emotion').size()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Emotion'

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE

# === STEP 1: DEFINE Anger_df ===
anger_df = df[[  # your base dataframe
    'Mean RR (ms)', 'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
    'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)', 'NN50 count',
    'pNN50 (%)', 'LF power (ms^2)', 'HF power (ms^2)', 'Total Power (ms^2)',
    'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2', 'Anger'
]].copy()

# === STEP 2: MAP 'Anger' LABELS TO INTS ===
anger_mapping = {'VeryLow': 0, 'Low': 0, 'Moderate': 1, 'High': 2, 'VeryHigh': 2}
anger_df['Anger Encoded'] = anger_df['Anger'].map(anger_mapping)

# Drop NaNs just in case (or alternatively you can fillna)
anger_df = anger_df.dropna()

# === STEP 3: EXTRACT FEATURES AND LABELS ===
feature_cols = anger_df.drop(columns=['Anger', 'Anger Encoded']).columns.tolist()
X = anger_df[feature_cols].values
y = anger_df['Anger Encoded'].values

# === STEP 4: BALANCE WITH SMOTE ===
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# === STEP 5: ONE-HOT ENCODE LABELS ===
encoder = OneHotEncoder(sparse_output=False, categories='auto')
y_resampled_onehot = encoder.fit_transform(y_resampled.reshape(-1, 1))

# === STEP 6: SPLIT ===
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled_onehot, test_size=0.2, random_state=42, stratify=y_resampled
)

# === STEP 7: SCALE ===
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# === STEP 8: COMPUTE CLASS WEIGHTS (even after SMOTE) ===
y_resampled_flat = np.argmax(y_resampled_onehot, axis=1)
class_weights = compute_class_weight('balanced', classes=np.unique(y_resampled_flat), y=y_resampled_flat)
class_weight_dict = dict(enumerate(class_weights))
print("✅ Class weights:", class_weight_dict)

# === STEP 9: BUILD MODEL ===
def build_model(input_dim, optimizer_choice='adam', learning_rate=0.001):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dense(3, activation='softmax')
    ])

    if optimizer_choice == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer_choice == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    elif optimizer_choice == 'rmsprop':
        optimizer = RMSprop(learning_rate=learning_rate)
    else:
        raise ValueError("Unsupported optimizer. Use 'adam', 'sgd', or 'rmsprop'.")

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

optimizer_choice = 'adam'
learning_rate = 0.001
model = build_model(X_train.shape[1], optimizer_choice, learning_rate)

# === STEP 10: TRAIN ===
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=16,
    class_weight=class_weight_dict,
    verbose=1
)

# === STEP 11: EVALUATE ===
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"✅ Final Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# === STEP 12: CLASSIFICATION REPORT ===
y_pred_probs = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

print("\n✅ Classification Report:")
print(classification_report(y_true_classes, y_pred_classes))

# === STEP 13: CONFUSION MATRIX PLOT ===
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# === STEP 14: TRAINING HISTORY PLOT ===
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ✅ Class weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0)}
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3545 - loss: 1.1493 - val_accuracy: 0.5248 - val_loss: 1.0314
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4942 - loss: 1.0505 - val_accuracy: 0.5792 - val_loss: 0.9936
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5158 - loss: 1.0332 - val_accuracy: 0.5891 - val_loss: 0.9690
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5245 - loss: 1.0205 - val_accuracy: 0.6040 - val_loss: 0.9527
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5755 - loss: 1.0042 - val_accuracy: 0.6089 - val_loss: 0.9296
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5320 - loss: 0.9695 - val_accuracy: 0.6287 - val_loss: 0.9208
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5310 - loss: 0.9834 - val_accuracy: 0.6188 - val_loss: 0.9038
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5597 - loss: 0.9616 - val_accuracy: 0.6188 - val_loss: 0.8968
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5405 - loss: 0.9577 - val_accuracy: 0.6287 - val_loss: 0.8799
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5872 - loss: 0.9376 - val_accuracy: 0.6337 - val_loss: 0.8713
# Epoch 11/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5604 - loss: 0.9357 - val_accuracy: 0.6535 - val_loss: 0.8653
# Epoch 12/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5537 - loss: 0.9466 - val_accuracy: 0.6238 - val_loss: 0.8607
# Epoch 13/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5948 - loss: 0.9045 - val_accuracy: 0.6238 - val_loss: 0.8483
# Epoch 14/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6106 - loss: 0.8795 - val_accuracy: 0.6436 - val_loss: 0.8445
# Epoch 15/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5931 - loss: 0.8857 - val_accuracy: 0.6386 - val_loss: 0.8320
# Epoch 16/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5799 - loss: 0.9083 - val_accuracy: 0.6782 - val_loss: 0.8308
# Epoch 17/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5864 - loss: 0.8964 - val_accuracy: 0.6683 - val_loss: 0.8320
# Epoch 18/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5956 - loss: 0.8648 - val_accuracy: 0.6584 - val_loss: 0.8275
# Epoch 19/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6210 - loss: 0.8702 - val_accuracy: 0.6683 - val_loss: 0.8274
# Epoch 20/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5875 - loss: 0.8620 - val_accuracy: 0.6584 - val_loss: 0.8153
# Epoch 21/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6212 - loss: 0.8490 - val_accuracy: 0.6535 - val_loss: 0.8099
# Epoch 22/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6414 - loss: 0.8222 - val_accuracy: 0.6634 - val_loss: 0.8077
# Epoch 23/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6216 - loss: 0.8574 - val_accuracy: 0.6733 - val_loss: 0.8105
# Epoch 24/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6034 - loss: 0.8585 - val_accuracy: 0.6782 - val_loss: 0.7969
# Epoch 25/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6027 - loss: 0.8701 - val_accuracy: 0.6782 - val_loss: 0.8101
# Epoch 26/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6170 - loss: 0.8397 - val_accuracy: 0.6782 - val_loss: 0.7996
# Epoch 27/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6210 - loss: 0.8553 - val_accuracy: 0.6634 - val_loss: 0.8100
# Epoch 28/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6378 - loss: 0.8197 - val_accuracy: 0.6881 - val_loss: 0.7896
# Epoch 29/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5972 - loss: 0.8587 - val_accuracy: 0.6733 - val_loss: 0.7881
# Epoch 30/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6390 - loss: 0.8227 - val_accuracy: 0.6683 - val_loss: 0.7868
# Epoch 31/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6290 - loss: 0.8517 - val_accuracy: 0.6931 - val_loss: 0.7720
# Epoch 32/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6423 - loss: 0.8104 - val_accuracy: 0.6931 - val_loss: 0.7827
# Epoch 33/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6765 - loss: 0.8040 - val_accuracy: 0.6733 - val_loss: 0.7802
# Epoch 34/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6396 - loss: 0.8205 - val_accuracy: 0.6782 - val_loss: 0.7819
# Epoch 35/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6445 - loss: 0.8123 - val_accuracy: 0.6980 - val_loss: 0.7729
# Epoch 36/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6323 - loss: 0.8263 - val_accuracy: 0.6980 - val_loss: 0.7715
# Epoch 37/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6604 - loss: 0.7964 - val_accuracy: 0.6931 - val_loss: 0.7757
# Epoch 38/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6651 - loss: 0.7750 - val_accuracy: 0.6881 - val_loss: 0.7655
# Epoch 39/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6598 - loss: 0.7843 - val_accuracy: 0.6881 - val_loss: 0.7670
# Epoch 40/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6206 - loss: 0.8129 - val_accuracy: 0.6881 - val_loss: 0.7659
# Epoch 41/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6703 - loss: 0.7545 - val_accuracy: 0.6980 - val_loss: 0.7557
# Epoch 42/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6789 - loss: 0.7607 - val_accuracy: 0.7129 - val_loss: 0.7537
# Epoch 43/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6650 - loss: 0.7556 - val_accuracy: 0.6832 - val_loss: 0.7624
# Epoch 44/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6237 - loss: 0.8162 - val_accuracy: 0.7030 - val_loss: 0.7592
# Epoch 45/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6665 - loss: 0.7597 - val_accuracy: 0.6782 - val_loss: 0.7507
# Epoch 46/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6435 - loss: 0.7956 - val_accuracy: 0.6782 - val_loss: 0.7497
# Epoch 47/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6107 - loss: 0.7912 - val_accuracy: 0.7079 - val_loss: 0.7487
# Epoch 48/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6523 - loss: 0.7960 - val_accuracy: 0.6881 - val_loss: 0.7472
# Epoch 49/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6337 - loss: 0.7874 - val_accuracy: 0.7030 - val_loss: 0.7447
# Epoch 50/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6497 - loss: 0.7772 - val_accuracy: 0.6931 - val_loss: 0.7521
# Epoch 51/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6827 - loss: 0.7570 - val_accuracy: 0.6881 - val_loss: 0.7517
# Epoch 52/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6479 - loss: 0.7636 - val_accuracy: 0.6931 - val_loss: 0.7379
# Epoch 53/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6392 - loss: 0.7664 - val_accuracy: 0.7079 - val_loss: 0.7442
# Epoch 54/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6917 - loss: 0.7266 - val_accuracy: 0.6980 - val_loss: 0.7319
# Epoch 55/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6537 - loss: 0.7618 - val_accuracy: 0.6931 - val_loss: 0.7391
# Epoch 56/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6619 - loss: 0.7582 - val_accuracy: 0.6881 - val_loss: 0.7255
# Epoch 57/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6721 - loss: 0.7685 - val_accuracy: 0.6980 - val_loss: 0.7461
# Epoch 58/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6848 - loss: 0.7259 - val_accuracy: 0.7178 - val_loss: 0.7242
# Epoch 59/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6434 - loss: 0.7647 - val_accuracy: 0.7228 - val_loss: 0.7213
# Epoch 60/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6487 - loss: 0.7507 - val_accuracy: 0.6881 - val_loss: 0.7239
# Epoch 61/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6857 - loss: 0.7189 - val_accuracy: 0.7079 - val_loss: 0.7208
# Epoch 62/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6456 - loss: 0.7627 - val_accuracy: 0.7079 - val_loss: 0.7202
# Epoch 63/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6782 - loss: 0.7308 - val_accuracy: 0.6931 - val_loss: 0.7227
# Epoch 64/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6909 - loss: 0.7359 - val_accuracy: 0.7030 - val_loss: 0.7177
# Epoch 65/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6693 - loss: 0.7185 - val_accuracy: 0.7079 - val_loss: 0.7299
# Epoch 66/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6625 - loss: 0.7367 - val_accuracy: 0.6980 - val_loss: 0.7213
# Epoch 67/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6873 - loss: 0.7068 - val_accuracy: 0.6931 - val_loss: 0.7165
# Epoch 68/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6931 - loss: 0.6986 - val_accuracy: 0.7129 - val_loss: 0.7202
# Epoch 69/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6601 - loss: 0.7549 - val_accuracy: 0.6931 - val_loss: 0.7106
# Epoch 70/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6895 - loss: 0.7081 - val_accuracy: 0.6733 - val_loss: 0.7142
# Epoch 71/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6736 - loss: 0.7068 - val_accuracy: 0.7129 - val_loss: 0.7166
# Epoch 72/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6735 - loss: 0.7297 - val_accuracy: 0.6733 - val_loss: 0.7167
# Epoch 73/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6849 - loss: 0.7345 - val_accuracy: 0.7327 - val_loss: 0.7136
# Epoch 74/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7049 - loss: 0.6903 - val_accuracy: 0.7129 - val_loss: 0.7098
# Epoch 75/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6846 - loss: 0.7302 - val_accuracy: 0.7079 - val_loss: 0.7133
# Epoch 76/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6846 - loss: 0.7008 - val_accuracy: 0.7079 - val_loss: 0.7114
# Epoch 77/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7112 - loss: 0.6862 - val_accuracy: 0.7178 - val_loss: 0.7198
# Epoch 78/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6577 - loss: 0.7225 - val_accuracy: 0.7079 - val_loss: 0.7020
# Epoch 79/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7032 - loss: 0.7110 - val_accuracy: 0.7079 - val_loss: 0.7208
# Epoch 80/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7118 - loss: 0.6686 - val_accuracy: 0.6980 - val_loss: 0.7069
# Epoch 81/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7079 - loss: 0.6786 - val_accuracy: 0.7228 - val_loss: 0.7048
# Epoch 82/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6493 - loss: 0.7231 - val_accuracy: 0.7277 - val_loss: 0.7017
# Epoch 83/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6798 - loss: 0.6845 - val_accuracy: 0.7327 - val_loss: 0.6885
# Epoch 84/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6752 - loss: 0.7061 - val_accuracy: 0.6832 - val_loss: 0.7016
# Epoch 85/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6571 - loss: 0.7165 - val_accuracy: 0.7178 - val_loss: 0.7040
# Epoch 86/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7198 - loss: 0.6522 - val_accuracy: 0.6980 - val_loss: 0.6828
# Epoch 87/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6959 - loss: 0.7117 - val_accuracy: 0.6584 - val_loss: 0.6993
# Epoch 88/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7031 - loss: 0.6695 - val_accuracy: 0.7228 - val_loss: 0.6901
# Epoch 89/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6726 - loss: 0.7093 - val_accuracy: 0.7178 - val_loss: 0.6867
# Epoch 90/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6691 - loss: 0.7175 - val_accuracy: 0.7129 - val_loss: 0.7016
# Epoch 91/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6962 - loss: 0.6814 - val_accuracy: 0.7079 - val_loss: 0.7073
# Epoch 92/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7025 - loss: 0.6820 - val_accuracy: 0.7178 - val_loss: 0.7077
# Epoch 93/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6689 - loss: 0.7045 - val_accuracy: 0.7079 - val_loss: 0.6944
# Epoch 94/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6941 - loss: 0.6739 - val_accuracy: 0.7178 - val_loss: 0.6893
# Epoch 95/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6921 - loss: 0.6818 - val_accuracy: 0.7426 - val_loss: 0.6799
# Epoch 96/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7001 - loss: 0.6654 - val_accuracy: 0.7030 - val_loss: 0.6849
# Epoch 97/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6738 - loss: 0.6850 - val_accuracy: 0.7376 - val_loss: 0.6786
# Epoch 98/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7271 - loss: 0.6373 - val_accuracy: 0.6782 - val_loss: 0.6910
# Epoch 99/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6748 - loss: 0.6904 - val_accuracy: 0.6733 - val_loss: 0.7021
# Epoch 100/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6825 - loss: 0.7005 - val_accuracy: 0.7624 - val_loss: 0.6676
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7642 - loss: 0.6191
# ✅ Final Test Loss: 0.6676, Test Accuracy: 0.7624
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# ✅ Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.60      0.71        67
#            1       0.73      0.93      0.82        67
#            2       0.73      0.76      0.75        68
#
#     accuracy                           0.76       202
#    macro avg       0.78      0.76      0.76       202
# weighted avg       0.78      0.76      0.76       202

# %%
model.save("anger_from_hrv_model.keras")
model.save("anger_from_hrv_model.h5")

import joblib

# Save
joblib.dump(scaler, 'anger_from_hrv_scaler.pkl')

from google.colab import files
files.download("anger_from_hrv_model.keras")
files.download("anger_from_hrv_model.h5")
files.download('anger_from_hrv_scaler.pkl')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
