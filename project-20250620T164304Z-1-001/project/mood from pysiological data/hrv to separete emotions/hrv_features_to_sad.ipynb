# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/project/hrv_features_to_emotion.csv")

# %%
df.head(2000)
# Out:
#      Participant Id  Session ID  Video ID Name  Age    Male  Valence level  \
# 0                 1           1         1  M_W   21  Female              6
# 1                 1           1         2  M_W   21  Female              2
# 2                 1           1         3  M_W   21  Female              7
# 3                 1           1         4  M_W   21  Female              7
# 4                 1           1         5  M_W   21  Female              0
# ..              ...         ...       ...  ...  ...     ...            ...
# 401              12           3         3  Q_M   11     NaN              4
# 402              12           3         4  Q_M   11     NaN              4
# 403              12           3         5  Q_M   11     NaN              4
# 404              12           3         6  Q_M   11     NaN              2
# 405              12           3         7  Q_M   11     NaN              2
#
#     Arousal level  Dominance level     Happy  ... NN50 count pNN50 (%)  \
# 0               0                0  Moderate  ...        0.0  0.000000
# 1               4                2   VeryLow  ...        0.0  0.000000
# 2               6                6  Moderate  ...        0.0  0.000000
# 3               3                4  Moderate  ...        0.0  0.000000
# 4               8                8   VeryLow  ...        0.0  0.000000
# ..            ...              ...       ...  ...        ...       ...
# 401             9                0   VeryLow  ...        0.0  0.000000
# 402             0                0      High  ...        0.0  0.000000
# 403             0                0  Moderate  ...        0.0  0.000000
# 404             7                2   VeryLow  ...        1.0  4.545455
# 405             3                3   VeryLow  ...        0.0  0.000000
#
#     LF power (ms^2) HF power (ms^2) LF/HF ratio Total Power (ms^2)   SD1 (ms)  \
# 0               0.0             0.0         NaN                0.0   4.481467
# 1               0.0             0.0         NaN                0.0   4.481467
# 2               0.0             0.0         NaN                0.0   4.331894
# 3               0.0             0.0         NaN                0.0   4.294365
# 4               0.0             0.0         NaN                0.0   4.244095
# ..              ...             ...         ...                ...        ...
# 401             0.0             0.0         NaN                0.0  10.433786
# 402             0.0             0.0         NaN                0.0  13.019616
# 403             0.0             0.0         NaN                0.0  13.962615
# 404             0.0             0.0         NaN                0.0  15.114610
# 405             0.0             0.0         NaN                0.0   7.330542
#
#       SD2 (ms)   SD1/SD2                                     Sample Entropy
# 0     9.282317  0.482796  (np.float64(1.6094379124341003), {'Dimension':...
# 1     9.282317  0.482796  (np.float64(1.6094379124341003), {'Dimension':...
# 2    10.567848  0.409913  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 3    12.243533  0.350746  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 4     6.771444  0.626764  (np.float64(1.9459101490553135), {'Dimension':...
# ..         ...       ...                                                ...
# 401  17.223026  0.605804  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 402  16.571814  0.785648  (np.float64(0.6931471805599453), {'Dimension':...
# 403  35.044618  0.398424  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
# 404  46.917721  0.322151  (np.float64(0.8873031950009028), {'Dimension':...
# 405  12.338483  0.594120  (inf, {'Dimension': 2, 'Delay': 1, 'Tolerance'...
#
# [406 rows x 49 columns]

# %%
print(df.columns)
# Out:
# Index(['Participant Id', 'Session ID', 'Video ID', 'Name', 'Age', 'Male',
#        'Valence level', 'Arousal level', 'Dominance level', 'Happy', 'Sad',
#        'Fear', 'Anger', 'Neutral', 'Disgust', 'Surprised', 'Familiarity Score',
#        'Emotion', 'Valence', 'Arousal', 'Four_Label', 'raw data', 'Gender',
#        'V_Label', 'A_Label', 'Four_Labels', 'R_Peaks', 'RR_Intervals',
#        'RR_Intervals_ms', 'Cleaned_RR_Intervals_ms', 'Mean RR (ms)',
#        'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
#        'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)',
#        'NN50 count', 'pNN50 (%)', 'LF power (ms^2)', 'HF power (ms^2)',
#        'LF/HF ratio', 'Total Power (ms^2)', 'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2',
#        'Sample Entropy'],
#       dtype='object')

# %%
sad_df = df[[
    'Mean RR (ms)', 'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
    'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)', 'NN50 count', 'pNN50 (%)',
    'LF power (ms^2)', 'HF power (ms^2)', 'Total Power (ms^2)', 'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2', 'Sad', 'Emotion'
]]

# %%
sad_df.groupby('Sad').size()
# Out:
# Sad
# High         29
# Low          62
# Moderate     34
# VeryHigh     28
# VeryLow     253
# dtype: int64

# %%
sad_df.groupby('Emotion').size()
# Out:
# Emotion
# Anger        28
# Disgust      34
# Fear         35
# Happy       120
# Mixed        88
# Neutral      37
# Sad          46
# Surprise     18
# dtype: int64

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE

# === STEP 1: DEFINE happy_df ===
sad_df = df[[  # your base dataframe
    'Mean RR (ms)', 'SDNN (ms)', 'Min RR (ms)', 'Max RR (ms)', 'Mean HR (bpm)',
    'STD HR (bpm)', 'Min HR (bpm)', 'Max HR (bpm)', 'RMSSD (ms)', 'NN50 count',
    'pNN50 (%)', 'LF power (ms^2)', 'HF power (ms^2)', 'Total Power (ms^2)',
    'SD1 (ms)', 'SD2 (ms)', 'SD1/SD2', 'Sad'
]].copy()

# === STEP 2: MAP 'Sad' LABELS TO INTS ===
sad_mapping = {'VeryLow': 0, 'Low': 0, 'Moderate': 0, 'High': 1, 'VeryHigh': 1}
sad_df['Sad Encoded'] = sad_df['Sad'].map(sad_mapping)

# Drop NaNs just in case (or alternatively you can fillna)
sad_df = sad_df.dropna()

# === STEP 3: EXTRACT FEATURES AND LABELS ===
feature_cols = sad_df.drop(columns=['Sad', 'Sad Encoded']).columns.tolist()
X = sad_df[feature_cols].values
y = sad_df['Sad Encoded'].values

# === STEP 4: BALANCE WITH SMOTE ===
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# === STEP 5: ONE-HOT ENCODE LABELS ===
encoder = OneHotEncoder(sparse_output=False, categories='auto')
y_resampled_onehot = encoder.fit_transform(y_resampled.reshape(-1, 1))

# === STEP 6: SPLIT ===
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled_onehot, test_size=0.2, random_state=42, stratify=y_resampled
)

# === STEP 7: SCALE ===
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# === STEP 8: COMPUTE CLASS WEIGHTS (even after SMOTE) ===
y_resampled_flat = np.argmax(y_resampled_onehot, axis=1)
class_weights = compute_class_weight('balanced', classes=np.unique(y_resampled_flat), y=y_resampled_flat)
class_weight_dict = dict(enumerate(class_weights))
print("✅ Class weights:", class_weight_dict)

# === STEP 9: BUILD MODEL ===
def build_model(input_dim, optimizer_choice='adam', learning_rate=0.001):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dense(2, activation='softmax')
    ])

    if optimizer_choice == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer_choice == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    elif optimizer_choice == 'rmsprop':
        optimizer = RMSprop(learning_rate=learning_rate)
    else:
        raise ValueError("Unsupported optimizer. Use 'adam', 'sgd', or 'rmsprop'.")

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

optimizer_choice = 'adam'
learning_rate = 0.001
model = build_model(X_train.shape[1], optimizer_choice, learning_rate)

# === STEP 10: TRAIN ===
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=16,
    class_weight=class_weight_dict,
    verbose=1
)

# === STEP 11: EVALUATE ===
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"✅ Final Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7435 - loss: 0.4938 - val_accuracy: 0.7071 - val_loss: 0.5821
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7331 - loss: 0.5040 - val_accuracy: 0.7071 - val_loss: 0.5695
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7143 - loss: 0.5197 - val_accuracy: 0.6929 - val_loss: 0.5795
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7431 - loss: 0.4979 - val_accuracy: 0.7071 - val_loss: 0.5758
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7375 - loss: 0.4989 - val_accuracy: 0.6857 - val_loss: 0.5734
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7305 - loss: 0.5101 - val_accuracy: 0.6857 - val_loss: 0.5898
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7234 - loss: 0.5225 - val_accuracy: 0.7000 - val_loss: 0.5732
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7379 - loss: 0.5203 - val_accuracy: 0.6929 - val_loss: 0.5838
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6788 - loss: 0.5711 - val_accuracy: 0.7071 - val_loss: 0.5784
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7107 - loss: 0.5451 - val_accuracy: 0.7071 - val_loss: 0.5678
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7211 - loss: 0.5132 - val_accuracy: 0.6929 - val_loss: 0.5833
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7308 - loss: 0.5089 - val_accuracy: 0.7143 - val_loss: 0.5667
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7625 - loss: 0.5016 - val_accuracy: 0.7000 - val_loss: 0.5728
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7145 - loss: 0.5156 - val_accuracy: 0.7071 - val_loss: 0.5784
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7429 - loss: 0.5140 - val_accuracy: 0.7214 - val_loss: 0.5750
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7351 - loss: 0.4909 - val_accuracy: 0.7143 - val_loss: 0.5746
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7586 - loss: 0.4789 - val_accuracy: 0.7143 - val_loss: 0.5702
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7411 - loss: 0.4936 - val_accuracy: 0.7143 - val_loss: 0.5819
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7291 - loss: 0.5127 - val_accuracy: 0.7071 - val_loss: 0.5704
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7476 - loss: 0.5165 - val_accuracy: 0.7214 - val_loss: 0.5652
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7303 - loss: 0.4894 - val_accuracy: 0.7143 - val_loss: 0.5692
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7457 - loss: 0.4955 - val_accuracy: 0.6929 - val_loss: 0.5677
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7474 - loss: 0.5021 - val_accuracy: 0.7071 - val_loss: 0.5722
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7558 - loss: 0.4878 - val_accuracy: 0.7143 - val_loss: 0.5716
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7221 - loss: 0.5339 - val_accuracy: 0.7214 - val_loss: 0.5648
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7415 - loss: 0.4825 - val_accuracy: 0.7214 - val_loss: 0.5671
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7365 - loss: 0.5108 - val_accuracy: 0.7286 - val_loss: 0.5698
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7437 - loss: 0.4921 - val_accuracy: 0.7214 - val_loss: 0.5637
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7213 - loss: 0.5250 - val_accuracy: 0.7214 - val_loss: 0.5738
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7238 - loss: 0.4982 - val_accuracy: 0.7357 - val_loss: 0.5660
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7383 - loss: 0.5466
# ✅ Final Test Loss: 0.5660, Test Accuracy: 0.7357
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# ✅ Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.72        70
#            1       0.71      0.80      0.75        70
#
#     accuracy                           0.74       140
#    macro avg       0.74      0.74      0.73       140
# weighted avg       0.74      0.74      0.73       140

# %%
model.save("sad_from_hrv_model.keras")
model.save("sad_from_hrv_model.h5")

import joblib

# Save
joblib.dump(scaler, 'sad_from_hrv_scaler.pkl')

from google.colab import files
files.download("sad_from_hrv_model.keras")
files.download("sad_from_hrv_model.h5")
files.download('sad_from_hrv_scaler.pkl')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
